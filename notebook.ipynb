# %% [markdown]
# <font color='DarkBlue' size=+2><b>Комментарий ревьюера</b></font><br>
# <font color='DarkBlue'>Привет, Даниил! <br>Меня зовут Олег Мазуренко, и я буду проверять этот проект. Спасибо за проделанную работу! <br>Ко мне можно обращаться на «ты». Как мне обращаться, напиши.</font><br>
# <font color='DarkBlue'>Я буду использовать различные цвета, чтобы было удобнее воспринимать мои комментарии:</font><br>
# <font color='DarkBlue'>Синий текст &mdash; просто текст комментария.</font><br>
# <font color='DarkGreen'>👌 Зеленый текст &mdash; все отлично.</font><br>
# <font color='DarkMagenta'>👉 Фиолетовый текст &mdash; сделано все правильно, однако есть рекомендации, на что стоит обратить внимание. Реализованные рекомендации позволят нам наработать опыт решения задачи разными способами или посмотреть на задачу под иным углом.</font><br>
# <font color='Red'>🛠 Красный текст &mdash; есть недочеты, они иногда бывают. </font><br><font color='DarkBlue'>Любая ошибка это возможность посмотреть на задачу с другой стороны и освоить новые знания, по этому не надо расстраиваться, если они есть.</font><br>
# <font color='DarkBlue'>Обращаю внимание, что комментарии ревьюера после проверки удалять нельзя они помогают отследить логику исправления или изменения проекта. Это дополнительный навык при обучении. Свой исправляемый код лучше тоже не удалять, а закомментировать символом `#`, тогда код остается, но не исполняется. Это позволит акцентировать изменения в ходе подготовки окончательного варианта проекта.<br>
# Ответы на мои комментарии лучше тоже помечать.
# Например: </font><font color='Blue'><b>Комментарий студента</b></font><br>
# <font color='DarkBlue'><b>Теперь посмотрим, что получилось!</b></font>

# %% [markdown]
# # Проект спринта 6 «Секреты Темнолесья»
#
# - Автор: Асначёв Даниил
# - Дата: 14.07.2026

# %% [markdown]
# ### Цели и задачи проекта
#
# Задача и цель проекта — познакомиться с данными и проанализировать их, проверить их корректность и провести предобработку.
# Перед анализом необходимо дополнительно сделать следующее:
#
# Отобрать данные по времени выхода игры. Нужен период с 2000 по 2013 год включительно.
# Категоризовать игры по оценкам пользователей и экспертов.
#
# Выделить три категории:
#
# высокая оценка — с оценкой от 8 до 10 и от 80 до 100, включая правые границы интервалов.
#
# средняя оценка — с оценкой от 3 до 8 и от 30 до 80, не включая правые границы интервалов.
#
# низкая оценка — с оценкой от 0 до 3 и от 0 до 30, не включая правые границы интервалов.
#
# Выделить топ-7 платформ по количеству игр, выпущенных за весь требуемый период.

# %% [markdown]
# ### Описание данных
#
# Name — название игры.
#
# Platform — название платформы.
#
# Year of Release — год выпуска игры.
#
# Genre — жанр игры.
#
# NA sales — продажи в Северной Америке (в миллионах проданных копий).
#
# EU sales — продажи в Европе (в миллионах проданных копий).
#
# JP sales — продажи в Японии (в миллионах проданных копий).
#
# Other sales — продажи в других странах (в миллионах проданных копий).
#
# Critic Score — оценка критиков (от 0 до 100).
#
# User Score — оценка пользователей (от 0 до 10).
#
# Rating — рейтинг организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.

# %% [markdown]
# ### Содержимое проекта
#
# 1. Загрузка и знакомство с данными
#
# 2. Проверка ошибок в данных и их предобработка
#
#     2.1 Приведение всех столбцов к стилю snake case
#
#     2.2 Преобразование типов данных
#
#     2.3 Обработка пропусков
#
#     2.4 Обработка дупликаотов
#
# 3. Фильтрация данных
#
# 4. Категоризация данных

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 01</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, сделано описание проекта. 👍 Оно помогает определиться над дальнейшей работой над проектом.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Любой проект, как учебный, так и реальный, начинается с его описания, содержащего: описание контекста, цель и краткий план исследования. Надо его написать, согласно шаблону в тренажере. <br>
# Обращаю внимание, что в тренажере при переходе по кнопке "Перейти к заданию" открывается тетрадка, в которой находится шаблон проекта, в котором сформирована структура проекта и задания брифа. Но после первой отправки проекта на ревью он замещается отправленной тетрадкой. Но его можно посмотреть и скачать по ссылке ниже:</font><br>
# https://drive.google.com/file/d/1yTGg6kUqkM648NUBJYPZfrpLIb0pJGyy/view?usp=sharing
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 1. Загрузка и знакомство с данными

# %%
import pandas as pd

df = pd.read_csv("/datasets/new_games.csv")
count_df_before = len(df)

print(count_df_before)
display(df.head(20))
df.info()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("/datasets/new_games.csv")
#       4 count_df_before = len(df)
#       6 print(count_df_before)
#
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 01</b></font><br>
# <font color='Red'>🛠 Ошибка кода не исправлена. Правильный путь к датасету а показал прошлый раз.</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Ошибка кода. Перед отправкой проекта на проверку надо проверять тетрадку на исполнение кода без ошибок. Так как при ошибке ревьюер должен прекратить проверку и вернуть проект. 😢 <br>В этот раз я сам вставлю код с правильной загрузкой датасета и перезапущу тетрадку, что бы ее можно было проверить до конца. Но потом я удалю свой код и ошибку придется исправлять самостоятельно.</font>
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий студента</b></font><br>
# Хочу разобраться, у меня код работал и работает:
# ![capture_20260714115035492.bmp](capture_20260714115035492.bmp)
# Я исправил, но не уверен, что это заработает. Если да, то просто нужно аналогичную папку создавать у себя на компьютере в будущем, чтобы у всех, кто работает над проектом, одинаково выглядел код чтения файла и не возникало ошибок, как сейчас, верно?
# По поводу шаблона: прошу прощения. У меня в яндекс браузере просто на самом сайте практикума проблемы с юпитером, поэтому у меня шаблон не отражался видимо. Я сам удивился, что нет шаблона.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 01</b></font><br>
# <font color='DarkMagenta'>👉 Неважно, работает ли код у исполнителя, в реальном проекте код должен работать у заказчика, в учебном проекте на Сервере Практикума. А для проверки работоспособности, необходимо перед отправкой на ревью проверять тетрадку на Сервере.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Лучше разделять по разным ячейкам загрузку библиотек и датасета.</font><br>
# <font color='DarkMagenta'>👉 Использование функции print() не позволяет вывести содержимое таблицы в виде удобном для анализа. Если имя таблицы находится в последней строке, исполняемой ячейки, то не нужны ни какие функции, в том числе и display(). Если выводим таблицу в середине ячейки (например, в теле цикла или функции), то используем display(). Рекомендация данная в тренажере относится к учебной платформе, в которой есть определенные ограничения, а тут эти функции в последней строке ячейки не нужны.</font><br>
# <font color='DarkGreen'>👌 Вот пример:</font>

# %%
# Комментарий ревьюера
display(df.head())
df.head()

# %% [markdown]
# 1. Сделайте вывод о полученных данных: данные какого объёма вам предоставили, соответствуют ли они описанию, встречаются ли в них пропуски, используются ли верные типы данных.
#
# 2. Отметьте другие особенности данных, которые вы обнаружили и на которые стоит обратить внимание при предобработке. Например, вы можете проверить названия столбцов: все ли названия отражают содержимое данных и прописаны в удобном для работы виде.

# %% [markdown]
# #### Первые выводы:
# 1. Первое, что можно заметить при анализе данных: года выпуска представлены типом float64. Это не критично, но стоит изменить на тип int64 для привычного восприятия. Аналогично все численные столбцы с рейтингами нужно изменить на тип float64, так как некоторые из них представлены типом object.
#
# 2. Для большого числа строк в таблице данных отсутствуют оценки критиков, пользователей и рейтинги. Интересно, что для двух строк в таблице известна платформа, но неизвестно название.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, сделали первичный анализ данных перед предобработкой.</font>

# %% [markdown]
# ## Проверка ошибок в данных и их предобработка
#
# ### 2.1 Приведение всех столбцов к стилю snake case

# %% [markdown]
# #### Названия, или метки, столбцов датафрейма:
#
# 1. Выведите на экран названия всех столбцов датафрейма и проверьте их стиль написания.
#
# 2. Приведите все столбцы к стилю snake case. Названия должны быть в нижнем регистре, а вместо пробелов — подчёркивания _.

# %%
print(df.columns)

# %%
new_columns = {'Name' : 'Name',
              'Platform': 'Platform',
              'Year of Release': 'Year_of_Release',
              'Genre': 'Genre',
              'NA sales': 'NA_sales',
              'EU sales': 'EU_sales',
              'JP sales': 'JP_sales',
              'Other sales': 'Other_sales',
              'Critic Score': 'Critic_Score',
              'User Score': 'User_Score',
              'Rating': 'Rating'}
df = df.rename(columns = new_columns)
df.columns = df.columns.str.lower()
display(df.head())

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо! Приводим названия колонок к общепринятому стилю. 😉 <br>
# А можно просто методом вот так:</font><br>
# `df.columns = df.columns.str.lower().str.replace(' ', '_')`

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Можно перед обработкой данных делать контроль размера датасета до и после обработки. Примерно вот так:</font>

# %%
# Комментарий ревьюера
# создаем копию датасета до преобразования для возможности проверить сделанные изменения после предобработки, 
# не следует этот датасет использовать в проекте, он только для проверки.
tmp = df.copy() 
len(tmp)

# %% [markdown]
# ### 2.2 Преобразование типов данных

# %% [markdown]
# #### Типы данных:
# 3. Если встречаются некорректные типы данных, предположите их причины.
#
# 4. При необходимости проведите преобразование типов данных. Помните, что столбцы с числовыми данными и пропусками нельзя преобразовать к типу int64. Сначала вам понадобится обработать пропуски, а затем преобразовать типы данных.
# В числовых столбцах могут встретиться строковые значения, например,unknown или другие. Приводите такие столбцы к числовому типу данных, заменив строковые значения на пропуски.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Следовало сделать анализ и выяснить, почему числовые данные (в столбцах `eu_sales`, `jp_sales`, `user_score`) имеют не числовой тип данных. Для этого следует вывести все уникальные значения по таким столбцам, определить ошибки и написать вывод.</font>

# %%
unique_eu_sales = df['eu_sales'].unique()
unique_jp_sales = df['jp_sales'].unique()
unique_user_score = df['user_score'].unique()
print(f"{unique_eu_sales} - unique_eu_sales")
print(f"{unique_jp_sales} - unique_jp_sales")
print(f"{unique_user_score} - unique_user_score")

# %% [markdown]
# В уникальных значениях столбца eu_sales и jp_sales  встречается значение 'unknown'. В уникальных значениях unique_user_score встречается значение nan и 'tbd'. В случае 'unknown' или nan данные просто не были найдены в открытых источниках. В случае 'tbd' - это просто опечатка.

# %%
cols = ['na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'critic_score', 'user_score']
df['year_of_release'] = pd.to_numeric(df['year_of_release'], errors='coerce', downcast = 'integer')
for col in cols:
    df[col] = pd.to_numeric(df[col], errors='coerce', downcast = 'float')

display(df.head())
df.info()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Обработка пропусков должна проводиться после их анализа в следующем разделе проекта.</font><br>
# <font color='DarkMagenta'>👉 Зачем заглушка (значение-индикатор) на пропуски года выпуска игр? Далее необходимо будет отфильтровывать датасет по году релиза и заглушки туда точно не войдут. Надо оценить % пропусков и принять правильное решение. Удалить напрочь.</font>

# %% [markdown]
# Основная пробелма в столбце year_of_release. Так как там присутсвуют значения NaN, то pandas автоматически переводит весь столбец в тип float64, из-за чего года отображаются непривычно. Для того, чтобы перевести всё к типу int16 (для меньшего объёма памяти), все значения NaN будут удалены ниже.

# %% [markdown]
# ### 2.3 Обработка пропусков

# %% [markdown]
# #### Наличие пропусков в данных:
# 5. Посчитайте количество пропусков в каждом столбце в абсолютных и относительных значениях.
#
# 6. Изучите данные с пропущенными значениями. Напишите промежуточный вывод: для каких столбцов характерны пропуски и сколько их. Предположите, почему пропуски могли возникнуть. Укажите, какие действия с этими данными можно сделать и почему.
#
# 7. Обработайте пропущенные значения. Для каждого случая вы можете выбрать оптимальный, на ваш взгляд, вариант: заменить на определённое значение, оставить как есть или удалить.Если вы решите заменить пропуски на значение-индикатор, то убедитесь, что предложенное значение не может быть использовано в данных.Если вы нашли пропуски в данных с количеством проданных копий игры в том или ином регионе, их можно заменить на среднее значение в зависимости от названия платформы и года выхода игры.

# %%
i = 0
for column in df.columns:
    i += 1
    print(f" {i}) {df[column].isna().sum()} - число пропусков в стобце {column}, {df[column].shape[0]} - общее число строк, {round((df[column].isna().sum()/df[column].shape[0]), 10)} - относительное число пропусков в столбце {column}")

# %%
count_nan_year_of_release = df['year_of_release'].isna().sum()
df = df.dropna(subset = ['year_of_release'])
df['year_of_release'] = df['year_of_release'].astype('int16')

# %% [markdown]
# Так как пропусков с годами было немного, то их решено было удалить

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно, что пропуски изучены в абсолютных и относительных значениях.</font>
# <br><font color='DarkMagenta'>👉 Только не следует выводить таблицы "принтами", можно сделать вот так:</font>

# %%
# Комментарий ревьюера
def show_missing_stats(tmp0):
    """
    Функция для отображения статистики пропущенных значений в DataFrame.
    """
    missing_stats = pd.DataFrame({
        'Кол-во пропусков': tmp0.isnull().sum(),
        'Доля пропусков': tmp0.isnull().mean()
    })
    missing_stats = missing_stats[missing_stats['Кол-во пропусков'] > 0]
    
    if missing_stats.empty:
        return "Пропусков в данных нет"
    
    # Форматируем при выводе через Styler
    return (missing_stats.style.format({'Доля пропусков': '{:.4f}'}).background_gradient(cmap='coolwarm'))
show_missing_stats(df)

# %%
display(df.loc[df['name'].isna() == True])
display(df.iloc[660:663], df.iloc[14438: 14441])

# %%
print(sum(df.duplicated(keep = False)))
df_loc_duplicate = df.loc[df.duplicated(keep = False)]
print('Все дубликаты', '\n', df_loc_duplicate)

cols_to_check = ['platform', 'year_of_release', 'na_sales', 'eu_sales', 'jp_sales', 'other_sales']

row_661 = df.loc[661, cols_to_check] 

duplicates_of_row_661 = df[(df[cols_to_check] == row_661).all(axis=1)]
print('Дубликаты строки 661', '\n', duplicates_of_row_661)

row_14439 = df.loc[14439, cols_to_check] 

duplicates_of_row_14439 = df[(df[cols_to_check] == row_14439).all(axis=1)]
print('Дубликаты строки 14439', '\n', duplicates_of_row_14439)

# %% [markdown]
# В столбце name есть два пропуска, что очень странно. У первого пропуска с номером 661 большое число продаж, поэтому его нельзя удалять. Нужно уточнить: может произошла ошибка при записи данных и название с жанром для этой игры не записались. У рядом стоящих строк данные в непустых столбцах не совпадают, дубликатов у строки нет. У второй строки продаж сильно меньше, но так же нет дубликатов. Так как в Японии указано число продаж порядка 30000, то строку лучше не удалять

# %%
print('Строки с пропусками в eu_sales', '\n', df.loc[df['eu_sales'].isna() == True], '\n')
print('Строки с пропусками в jp_sales', '\n', df.loc[df['jp_sales'].isna() == True])

# %%
def fill_na_with_mean(group):
    return group.fillna(group.mean())


original_eu_sales = df.loc[df['genre'].isna(), 'eu_sales'].copy()
original_jp_sales = df.loc[df['genre'].isna(), 'jp_sales'].copy()


mask = df['genre'].notna()
df.loc[mask, 'eu_sales'] = df.loc[mask].groupby(['platform', 'year_of_release'], group_keys=False)['eu_sales'].apply(fill_na_with_mean)
df.loc[mask, 'jp_sales'] = df.loc[mask].groupby(['platform', 'year_of_release'], group_keys=False)['jp_sales'].apply(fill_na_with_mean)

df.loc[df['genre'].isna(), 'eu_sales'] = original_eu_sales
df.loc[df['genre'].isna(), 'jp_sales'] = original_jp_sales

# Изначально было так, но потом я обнаружил, что из-за того, что в строчках 661 и 14439 нет жанра, то у них данные удаляются
# df['eu_sales'] = df.groupby(['platform', 'year_of_release', 'genre'], group_keys=False)['eu_sales'].apply(fill_na_with_mean)
# df['jp_sales'] = df.groupby(['platform', 'year_of_release', 'genre'], group_keys=False)['jp_sales'].apply(fill_na_with_mean)

display(df.iloc[[446, 802, 1131, 1132, 1394, 1612]])
display(df.iloc[[467, 819, 1379, 4732]])

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не корректно сделана замена пропусков, необходимо заменить средним значением по столбцам платформ и году релиза, жанры к замене пропусков не имеют отношения.</font>

# %% [markdown]
# Для столбцов eu_sales и jp_sales небольшое количество пропусков, поэтому их можно заменить на средние значения для игр того же года выпуска, с той же платформой и того же жанра. Пропуски могли возниккуть просто из-за нехватки информации, не всё можно найти в открытых источниках.

# %% [markdown]
# Для столбцов с рейтингом и оценками количество пропусков достигает 40-50%, что очень много.

# %%
df['user_score'] = df['user_score'].fillna(-1)
df['critic_score'] = df['critic_score'].fillna(-1)
df['rating'] = df['rating'].fillna('unknown')

# %%
i = 0
for column in df.columns:
    i += 1
    print(f" {i}) {df[column].isna().sum()} - число пропусков в стобце {column}, {df[column].shape[0]} - общее число строк, {round((df[column].isna().sum()/df[column].shape[0]), 10)} - относительное число пропусков в столбце {column}")


print('Строки с пропусками в critic_score', '\n', df.loc[df['critic_score'].isna() == True], '\n')
print('Строки с пропусками в user_score', '\n', df.loc[df['user_score'].isna() == True])

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Почему считаем, что такая замена пропусков колонок отзывов корректна?</font><br>
# <font color='DarkMagenta'>👉 Проще поставить на них заглушку (значение-индикатор) в виде отрицательной цифры.</font><br>
# <font color='DarkMagenta'>👉 Ошибка в подходе к заполнению пропусков в колонках отзывов средним/медианой/модой или синтетическими данными, извлекаемыми из данных других колонок, связана с тем, что данные этих колонок не являются набором случайных наблюдений. <br>Если бы здесь была выборка оценок пользователей по отзывам на одну игру, то ее можно было считать случайными данными. Один пользователь поставил отметку 1, другой 10. Одному игра не понравилась, другому понравилсь. Пропуски в такой выборке можем заменить средним/медианой/модой, так как все данные относятся к одной и той же игре. <br>В данном случае отзыв как раз и является таким усреднением выборки оценок пользователей по одной игре и является признаком именно этой игры, не зависящей от жанра, платформы и т.д. Более того, если внимательно посмотреть на датасет, то можем найти примеры, когда одна игра на разных платформах имеет двукратное различие в оценках пользователей. Возможно, что не на всех платформах можно достичь высокого качества графики, скорости и т.д.<br>Так же формируется и отзыв критиков. Определенное количество критиков протестировало игру, выставило свою оценку, которую потом усреднили и присвоили конкретной игре. То есть отзыв критиков стал интегрированным признаком конкретной игры и не зависит от жанра, платформы и т.д.<br>
# По этому пропуски отзывов нельзя заполнять синтетическими данными извлекаемыми из оценок других игр.<br>
# Задача при анализе датасета и обработке пропусков заключается определить, что собой представляют данные и какие реальные бизнес-процессы они описывают. И в зависимости от этого принимать решение об обработке.</font>

# %% [markdown]
# Переделал, теперь для user_score и critic_score

# %%
# Комментарий ревьюера
# Посмотрим какие пропуски остались
show_missing_stats(df)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 Я бы порекомендовал посмотреть в инете, что означает рейтинг ESRB, тогда бы узнали, что это рейтинг для США и Канады. А значит пропуск не связан с ошибкой заполнения данных, просто не только для Северной Америки выпускаются игры. И пропуски в этой колонке не являются просто ошибкой заполнения данных, а несут определенную информацию. Что бы проанализировать ее, на пропуски следует поставить заглушку. В данном проекте не требуется анализ возрастного рейтинга, но тем не менее предобработка данных должна быть выполнена в полном объеме.<br>
# На скрине ниже представлен анализ возрастного рейтинга, показывающий предпочтения пользователей Японии региональным играм, то есть без рейтинга ESRB.</font>
# ![image.png](attachment:image.png)

# %% [markdown]
# Значения nan в столбце rating были заменены на 'unknown'

# %% [markdown]
# ### 2.4 Обработка дупликаотов

# %% [markdown]
# #### Явные и неявные дубликаты в данных:
# 1. Изучите уникальные значения в категориальных данных, например с названиями жанра игры, платформы, рейтинга и года выпуска. Проверьте, встречаются ли среди данных неявные дубликаты, связанные с опечатками или разным способом написания.
#
# 2. При необходимости проведите нормализацию данных с текстовыми значениями. Названия или жанры игр можно привести к нижнему регистру, а названия рейтинга — к верхнему.
#
# 3. После того как нормализуете данные и устраните неявные дубликаты, проверьте наличие явных дубликатов в данных.
#
# 4. Напишите промежуточный вывод: укажите количество найденных дубликатов и действия по их обработке.

# %%
for column in df.columns:
    if column in ['name', 'platform', 'genre', 'rating', 'year_of_release']:
        print(f"{df[column].unique()} - уникальные значения столбца {column}")
print(f"{len(df['name'].unique())} - уникальные значения в {'name'}, {len(df['name'])} - все значения в {'name'}")

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, сделали проверку уникальных значений в столбцах с категориальными данными.</font>

# %%
df['name'] = df['name'].str.lower()
df['genre'] = df['genre'].str.lower()
for column in df.columns:
    if column in ['name', 'platform', 'genre', 'rating']:
        print(f"{df[column].unique()} - уникальные значения столбца {column}")

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Правильно сделано преобразование регистров данных, тем самым удалены неявные дубликаты.</font>

# %%
print(sum(df.duplicated(keep = False)))
df_loc_duplicate = df.loc[df.duplicated(keep = False)]
print('Все дубликаты', '\n', df_loc_duplicate)

# %%
count_duplicate = sum(df.duplicated(keep = False))
df = df.drop_duplicates(keep = 'first')
count_df_after = len(df)

# %% [markdown]
# Всего было найдено 422 дубликата после всех предыдущих этапов предобработки. Все дубликаты удалены, кроме первых вхождений.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, что удалены явные дубликаты, в дальнейшем они искажают результаты анализа.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Вот, что написано в задании: <br><b>В процессе подготовки данных вы могли удалять данные, например строки с пропусками или ошибками, дубликаты и прочее. В этом случае посчитайте количество удалённых строк в абсолютном и относительном значениях. После проведения предобработки данных напишите общий промежуточный вывод.</b> <br>А это не сделано.</font>

# %%
print(f" {count_nan_year_of_release + count_duplicate} - абсолютное число удалённых строк,\n {count_df_before} - общее чсило строк до предобработки,\n {count_df_after} - общее число строк после обработки,\n {(count_nan_year_of_release + count_duplicate) / count_df_before} - относительное число удалённых строк для начальной таблицы,\n {(count_nan_year_of_release + count_duplicate) / count_df_after} - относительное число удалённых строк для таблицы после обработки")

# %% [markdown]
# В результате предобработки данных было удалено около 4.5% данных из-за дубликатов и пустых значений. Устранены некоторые опечатки в данных: для неизвестных значений продаж посчитаны средние значения на основе группировки по году и платформе, изменены типы данных на соответсвующие числовые. Для двух игр с большим количеством продаж отсутсвуют названия и жанры.

# %% [markdown]
# ## Фильтрация данных

# %% [markdown]
# ## 4. Категоризация данных

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Вот, что написано в задании: <br><b>Фильтрация данных<br>
# Коллеги хотят изучить историю продаж игр в начале XXI века, и их интересует период с 2000 по 2013 год включительно. Отберите данные по этому показателю. Сохраните новый срез данных в отдельном датафрейме, например df_actual.</b> <br>А это не сделано.</font>

# %%
df_actual = df[(df['year_of_release'] >= 2000) & (df['year_of_release'] <= 2013)].copy()
df_actual['user_score_rating'] = pd.cut(df_actual['user_score'], bins=[0, 3, 8, 10], labels=['низкая оценка', 'средняя оценка', 'высокая оценка'], right=False)
df_actual['critic_score_rating'] = pd.cut(df_actual['critic_score'], bins=[0, 30, 80, 100], labels=['низкая оценка', 'средняя оценка', 'высокая оценка'], right=False)
display(df_actual.head(10))
df.info()

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Ошибка категоризации, см.код ниже. В методе `.cut`, как написано в документации, по умолчанию используется параметр `right=True`. Это означает, что параметр `bins` захватывает правые границы диапазона. В итоге категоризация сделана не  корректно.<br>Это можно исправить, или написанием функции для каждого вида отзывов, в которых сделать цикл проверяющий значение по условию и возвращающие соответствующую категорию. А данные с пропусками можно отнести в категорию "без оценки". Затем методом `.apply()` обработать необходимые столбцы датасета. <br>Или использовать в методе `.cut` параметр `right=False` для установки правильных границ. </font>

# %%
# Комментарий ревьюера
# Проверяем границы категорий по заданию брифа и созданные в проекте
tmp0, u_s, c_s = df_actual.copy(), 'user_score', 'critic_score'
cat_u, cat_c = 'user_score_rating', 'critic_score_rating'
print("Оценка 8 должна относиться категории 'высокая оценка'", "здесь это",
      tmp0[tmp0[u_s] == 8][cat_u].unique())
print("Оценка 3 должна относиться категории 'средняя оценка'", "здесь это",
      tmp0[tmp0[u_s] == 3][cat_u].unique())
print("Оценка 0 должна относиться категории 'низкая оценка'", "здесь это",
      tmp0[tmp0[u_s] == 0][cat_u].unique())
print("=================================")
print("Оценка 80 должна относиться категории 'высокая оценка'", "здесь это",
      tmp0[tmp0[c_s] == 80][cat_c].unique())
print("Оценка 30 должна относиться категории 'средняя оценка'", "здесь это",
      tmp0[tmp0[c_s] == 30][cat_c].unique())
print("Оценка 0 должна относиться категории 'низкая оценка'", "здесь это",
      tmp0[tmp0[c_s] == 0][cat_c].unique())

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Не проведена проверка категоризации данных по отзывам пользователей и критиков. Следует вывести на экран таблицу с количеством игр по категориям и видам отзывов.</font>
# ![image.png](attachment:image.png)

# %%
if 'без оценки' not in df_actual['critic_score_rating'].cat.categories:
    df_actual['critic_score_rating'] = df_actual['critic_score_rating'].cat.add_categories(['без оценки'])

if 'без оценки' not in df_actual['user_score_rating'].cat.categories:
    df_actual['user_score_rating'] = df_actual['user_score_rating'].cat.add_categories(['без оценки'])

df_actual['critic_score_rating'] = df_actual['critic_score_rating'].fillna('без оценки')
df_actual['user_score_rating'] = df_actual['user_score_rating'].fillna('без оценки')


score_1 = df_actual.groupby('critic_score_rating', as_index=False).agg(
    critic_score_cat=('name', 'count'))
score_2 = df_actual.groupby('user_score_rating', as_index=False).agg(
    user_score_cat=('name', 'count'))

score_1 = score_1.rename(columns={'critic_score_rating': 'critic_score_cat', 'critic_score_cat': 'name'}).sort_values(by='name', ascending=True)
score_2 = score_2.rename(columns={'user_score_rating': 'user_score_cat', 'user_score_cat': 'name'}).sort_values(by='name', ascending=True)

display(score_1, score_2)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Вот, что написано в задании: <br><b>Выделите топ-7 платформ по количеству игр, выпущенных за весь актуальный период.</b> <br>А это не сделано.</font>

# %%
platform_counts = df_actual.groupby('platform')['name'].count().sort_values(ascending=False)

top_platforms = platform_counts.head(7).index.tolist()

print("Топ-7 платформ по количеству игр (2000–2013):")
display(platform_counts.head(7))

# %% [markdown]
# # Итоговый вывод по работе
#
# Перед фильтрацией данных была проделана предобработка данных. Вот основные изменения и наблюдения по таблице:
# 1. Приведены все столбцы к стилю snake case.
#
# 2. Был изменён тип столбцы year_of_release c float64 на int16, все пустые ячейки удалены.
#
# 3. В столбце с названиями игр было обнаружено две строчки без названий игр и их жанров. Так как в столбцах с продажами данные не нулевые и по этим данным нет дубликатов, то эти игры стоит перепроверить, может названия просто не записались.
#
# 4. Для столбцов eu_sales и jp_sales присутствовало небольшое количество пропусков, поэтому они были заменены на средние значения для игр того же года выпуска и с той же платформой.
#
# 5. Нет особой зависимости от платформы, жанра или года выпуска для отсутствия данных в оценках пользователей, критиков или в рейтинге. Так как отсутсвует почти половина, то все эти значения nan были заменены на -1
#
# 6. Названия игр и жанры были приведены к нижнему регистру.
#
# 7. Всего было найдено 422 дубликата после всех предыдущих этапов предобработки. Все дубликаты удалены, кроме первых вхождений.
#
# Описание данных после фильтрации:
#
# name — название игры.
#
# platform — название платформы.
#
# year_of_release — год выпуска игры.
#
# genre — жанр игры.
#
# na_sales — продажи в Северной Америке (в миллионах проданных копий).
#
# eu_sales — продажи в Европе (в миллионах проданных копий).
#
# jp_sales — продажи в Японии (в миллионах проданных копий).
#
# other_sales — продажи в других странах (в миллионах проданных копий).
#
# critic_score — оценка критиков (от 0 до 100).
#
# user_score — оценка пользователей (от 0 до 10).
#
# rating — рейтинг организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# user_score_rating - разделение всех игр по оценкам пользователей
#
# critic_score_rating - разделение всех игр по оценкам критиков
#
# После фильтрации и категоризации данных, что больше всего игр без оценок пользователей или критиков, дальше идут игры с средними рейтингами, высокими и в конце с низкими. Топ - 7 платформ по играм: PS2, DS, Wii, PSP, X360, PS3, GBA

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Итоговый вывод необходимо будет переделать после исправления ошибок.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера</b></font><br><br>
# <font color='DarkGreen'>👌 Даниил, проект проработан.<br>Так держать и дальше!<br></font>
# <font color='Red'>🛠 Что нужно, что бы сделать проект лучше:</font><br>
# <font color='Red'>🛠 Необходимо сделать описание проекта. Исправить код загрузки датасета. Сделать анализ причин не корректных данных в количественных столбцах. Переделать обработку пропусков в столбцах с продажами. Переделать обработку пропусков в отзывах пользователей и критиков. Сделать расчет удаленных строк датасета после обработки. Написать промежуточный вывод по предобработке данных. Отфильтровать датасет по годам релиза. Переделать категоризацию оценок пользователей и критиков. Сделать проверку категоризации данных отзывов. Сделать вывод ТОП-7 платформ по количеству игр. Переделать итоговый вывод проекта.</font><br>
# <font color='DarkMagenta'>👉 При исправлении ошибок и недочетов будут приобретены дополнительный опыт и навыки!</font><br>
# <font color='DarkGreen'>👌 Жду окончательный вариант! Успехов.</font>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера 01</b></font><br>
# <font color='DarkGreen'>👌 Даниил!<br></font>
# <font color='Red'>🛠 Увы, должен прервать ревью из-за ошибки в коде. Настоятельно рекомендую перед отправкой проекта на ревью проверять в JupyterHub исполнение кода тетрадки (см.скрин ниже).<br>
# Жду исправленный проект. Если будут трудности, можно обратиться к наставнику. </font>
# ![image.png](attachment:image.png)
